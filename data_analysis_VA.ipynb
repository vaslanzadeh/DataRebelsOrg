# %%
Load pac

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# list datasets

# %%
life_expectancy = 'Datasets/lifeexpectancy_by_counties.csv'
health_indicators = 'Datasets/ScottishHealthSurveyDataByLocalAuthorities.csv'
freq_use_green = 'Datasets/SHS_Frequency_of_use_of_nearest_green_or_blue_space.csv'
statisfaction_facilities = 'Datasets/SHS_Satisfaction_with_local_authority_sports_and_leisure_facilities.csv'
use_of_facilities ='Datasets/SHS_Use_of_local_authority_sports_and_leisure_facilities.csv'
walking_distance ='Datasets/SHS_Walking_distance_to_nearest_green_or_blue_space.csv'

# %% [markdown]
# read datasets

# %%
life_expectancy_df = pd.read_csv(life_expectancy)
health_indicators_df = pd.read_csv(life_expectancy)
freq_use_green_df = pd.read_csv(freq_use_green)
statisfaction_facilities_df = pd.read_csv(statisfaction_facilities)
use_of_facilities_df = pd.read_csv(use_of_facilities)
walking_distance_df = pd.read_csv(walking_distance)

# %% [markdown]
# ## life_expectancy data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(life_expectancy_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(life_expectancy_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(life_expectancy_df[life_expectancy_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(life_expectancy_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(life_expectancy_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335160 entries, 0 to 335159
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Period                     335160 non-null  object
#  1   Country                    335160 non-null  object
#  2   Area type                  335160 non-null  object
#  3   Area code                  335160 non-null  object
#  4   Area name                  335160 non-null  object
#  5   Sex                        335160 non-null  object
#  6   Sex code                   335160 non-null  int64
#  7   Age band                   335160 non-null  int64
#  8   Age group                  335160 non-null  object
#  9   Life expectancy            335160 non-null  float64
#  10  Lower confidence interval  335160 non-null  float64
#  11  Upper confidence interval  335160 non-null  float64
# dtypes: float64(3), int64(2), object(7)
# ...

# %% [markdown]
# ## health_indicators data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(health_indicators_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(health_indicators_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(health_indicators_df[health_indicators_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(health_indicators_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(health_indicators_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335160 entries, 0 to 335159
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Period                     335160 non-null  object
#  1   Country                    335160 non-null  object
#  2   Area type                  335160 non-null  object
#  3   Area code                  335160 non-null  object
#  4   Area name                  335160 non-null  object
#  5   Sex                        335160 non-null  object
#  6   Sex code                   335160 non-null  int64
#  7   Age band                   335160 non-null  int64
#  8   Age group                  335160 non-null  object
#  9   Life expectancy            335160 non-null  float64
#  10  Lower confidence interval  335160 non-null  float64
#  11  Upper confidence interval  335160 non-null  float64
# dtypes: float64(3), int64(2), object(7)
# ...

# %% [markdown]
# ## freq_use_green data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(freq_use_green_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(freq_use_green_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(freq_use_green_df[freq_use_green_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(freq_use_green_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(freq_use_green_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  264 non-null    int64
#  1   Council     264 non-null    object
#  2   Unnamed: 2  264 non-null    object
#  3   2013        264 non-null    object
#  4   2014        264 non-null    object
#  5   2015        264 non-null    object
#  6   2016        264 non-null    object
#  7   2017        264 non-null    object
#  8   2019        264 non-null    object
#  9   2023        264 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 20.8+ KB
# None
#
# Empty Fields:
# Unnamed: 0    0
# Council       0
# Unnamed: 2    0
# 2013          0
# 2014          0
# 2015          0
# 2016          0
# 2017          0
# 2019          0
# 2023          0
# dtype: int64
#
# Errors:
# Empty DataFrame
# ...

# %% [markdown]
# ## statisfaction_facilities data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(statisfaction_facilities_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(statisfaction_facilities_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(statisfaction_facilities_df[statisfaction_facilities_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(statisfaction_facilities_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(statisfaction_facilities_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    198 non-null    int64
#  1   Council       198 non-null    object
#  2   Satisfaction  198 non-null    object
#  3   2007/2008     198 non-null    float64
#  4   2009/2010     198 non-null    float64
#  5   2011          198 non-null    object
#  6   2012          198 non-null    float64
#  7   2013          198 non-null    float64
#  8   2014          198 non-null    float64
#  9   2015          198 non-null    float64
#  10  2016          198 non-null    float64
#  11  2017          198 non-null    float64
#  12  2018          198 non-null    float64
#  13  2019          198 non-null    float64
#  14  2022          198 non-null    float64
#  15  2023          198 non-null    float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 24.9+ KB
# ...

# %% [markdown]
# ## use_of_facilities data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(use_of_facilities_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(use_of_facilities_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(use_of_facilities_df[use_of_facilities_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(use_of_facilities_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(use_of_facilities_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Council     198 non-null    object
#  2   serv2a      198 non-null    object
#  3   2007/2008   198 non-null    object
#  4   2009/2010   198 non-null    object
#  5   2011        198 non-null    object
#  6   2012        198 non-null    object
#  7   2013        198 non-null    object
#  8   2014        198 non-null    object
#  9   2015        198 non-null    object
#  10  2016        198 non-null    object
#  11  2017        198 non-null    object
#  12  2018        198 non-null    object
#  13  2019        198 non-null    object
#  14  2022        198 non-null    object
#  15  2023        198 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 24.9+ KB
# None
#
# Empty Fields:
# Unnamed: 0    0
# Council       0
# ...

# %% [markdown]
# ## walking_distance data summary

# %%
# Display the structure of the data
print("Data Structure:")
print(walking_distance_df.info())

# Check for empty fields
print("\nEmpty Fields:")
print(walking_distance_df.isnull().sum())

# Check for errors (assuming errors are represented as NaN or invalid data types)
print("\nErrors:")
print(walking_distance_df[walking_distance_df.isnull().any(axis=1)])

# Display the first few rows of the data
print("\nFirst few rows of the data:")
print(walking_distance_df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(walking_distance_df.describe())
# Out:
# Data Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        198 non-null    int64
#  1   Council           198 non-null    object
#  2   Walking distance  198 non-null    object
#  3   2013              198 non-null    object
#  4   2014              198 non-null    object
#  5   2015              198 non-null    object
#  6   2016              198 non-null    object
#  7   2017              198 non-null    object
#  8   2018              198 non-null    object
#  9   2019              198 non-null    object
#  10  2022              198 non-null    object
#  11  2023              198 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 18.7+ KB
# None
#
# Empty Fields:
# Unnamed: 0          0
# Council             0
# Walking distance    0
# 2013                0
# 2014                0
# ...
